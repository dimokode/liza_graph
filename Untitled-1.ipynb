# %%
# !which python
# Out:
# /Users/admin/deaplearning/.venv/bin/python

# %%
import nltk
from nltk import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import wordnet
from nltk.corpus import stopwords

from pymystem3 import Mystem

import pymorphy3

# %%
morph = pymorphy3.MorphAnalyzer()

# %%
lemmatizer = WordNetLemmatizer()

# %%
text = "соревновались зимой"

# %%
sw = stopwords.words('russian')

# %%
def tokenize(text):
    tokenized_text = word_tokenize(text, language='russian')
    return [token.lower() for token in tokenized_text if token.lower() not in sw]

# %%
tokens = tokenize(text)
tokens
# Out:
# ['мамы', 'окне', 'кот', 'моет', 'раму']

# %%
def lemmatize(text):
    lemmas = [morph.parse(token)[0].normal_form for token in text]
    return lemmas

# %%
def parse_text(text):
    return [morph.parse(token)[0] for token in text]

# %%
result = lemmatize(tokens)
result
# Out:
# ['мама', 'окно', 'кот', 'мыть', 'рама']

# %%
text_data = parse_text(tokens)
text_data
# Out:
# [Parse(word='мамы', tag=OpencorporaTag('NOUN,anim,femn sing,gent'), normal_form='мама', score=0.666666, methods_stack=((DictionaryAnalyzer(), 'мамы', 1987, 1),)),
#  Parse(word='окне', tag=OpencorporaTag('NOUN,inan,neut sing,loct'), normal_form='окно', score=1.0, methods_stack=((DictionaryAnalyzer(), 'окне', 906, 5),)),
#  Parse(word='кот', tag=OpencorporaTag('NOUN,anim,masc sing,nomn'), normal_form='кот', score=1.0, methods_stack=((DictionaryAnalyzer(), 'кот', 52, 0),)),
#  Parse(word='моет', tag=OpencorporaTag('VERB,impf,tran sing,3per,pres,indc'), normal_form='мыть', score=1.0, methods_stack=((DictionaryAnalyzer(), 'моет', 2073, 5),)),
#  Parse(word='раму', tag=OpencorporaTag('NOUN,inan,femn sing,accs'), normal_form='рама', score=0.888888, methods_stack=((DictionaryAnalyzer(), 'раму', 55, 3),))]

# %%
def get_text_data(text):
    return { token:(morph.parse(token)[0].normal_form, morph.parse(token)[0].tag.POS) for token in text}

# %%
data = get_text_data(tokens)
data
# Out:
# {'мамы': ('мама', 'NOUN'),
#  'окне': ('окно', 'NOUN'),
#  'кот': ('кот', 'NOUN'),
#  'моет': ('мыть', 'VERB'),
#  'раму': ('рама', 'NOUN')}
